# %%
import numpy as np
import pandas as pd
from ID3_Fucntion import ID3

# %%
df = pd.read_csv('weather_train.csv')
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
df
# Out:
#    temperature   outlook humidity    wind play
# 0          hot     sunny     high    weak   no
# 1          hot     sunny     high  strong   no
# 2          hot  overcast     high    weak  yes
# 3         mild     rainy     high    weak  yes
# 4         cool     rainy   normal    weak  yes
# 5         cool     rainy   normal  strong   no
# 6         cool  overcast   normal  strong  yes
# 7         mild     sunny     high    weak   no
# 8         cool     sunny   normal    weak  yes
# 9         mild     rainy   normal    weak  yes
# 10        mild     sunny   normal  strong  yes
# 11        mild  overcast     high  strong  yes
# 12         hot  overcast   normal    weak  yes
# 13        mild     rainy     high  strong   no

# %%
decision_tree = ID3(max_high = 3, min_branch = 2)

# %%
decision_tree.fit(X,y)
# Out:
# `- (None)outlook
#    |- (sunny)humidity
#    |  |- (high)no
#    |  `- (normal)yes
#    |- (overcast)yes
#    `- (rainy)humidity
#       |- (high)yes
#       `- (normal)yes
# C:\Users\vicen\Anaconda3\lib\site-packages\pandas\core\series.py:942: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]

# %%
df = pd.read_csv('weather_predict.csv')
df
# Out:
#    temperature   outlook humidity    wind
# 0          hot     sunny     high    weak
# 1          hot     sunny     high  strong
# 2          hot  overcast     high    weak
# 3         mild     rainy     high    weak
# 4         cool     rainy   normal    weak
# 5         cool     rainy   normal  strong
# 6         cool  overcast   normal  strong
# 7         mild     sunny     high    weak
# 8         cool     sunny   normal    weak
# 9         mild     rainy   normal    weak
# 10        mild     sunny   normal  strong
# 11        mild  overcast     high  strong
# 12         hot  overcast   normal    weak
# 13        mild     rainy     high  strong

# %%
# start from root and recursively travel if not meet a leaf
predict = decision_tree.predict(df)
df ['predict'] = predict

# %%
df
# Out:
#    temperature   outlook humidity    wind predict
# 0          hot     sunny     high    weak      no
# 1          hot     sunny     high  strong      no
# 2          hot  overcast     high    weak     yes
# 3         mild     rainy     high    weak     yes
# 4         cool     rainy   normal    weak     yes
# 5         cool     rainy   normal  strong     yes
# 6         cool  overcast   normal  strong     yes
# 7         mild     sunny     high    weak      no
# 8         cool     sunny   normal    weak     yes
# 9         mild     rainy   normal    weak     yes
# 10        mild     sunny   normal  strong     yes
# 11        mild  overcast     high  strong     yes
# 12         hot  overcast   normal    weak     yes
# 13        mild     rainy     high  strong     yes

# %%
df.to_csv('output.csv')
